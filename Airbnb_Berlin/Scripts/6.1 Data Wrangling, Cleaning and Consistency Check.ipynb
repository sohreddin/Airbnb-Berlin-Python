# %% [markdown]
# # <font color=darkpink>Airbnb Berlin</font>
#
# This script contains the following points:
#
#  - 1. Import libraries
#  - 2. Import data
#  - 3. Data Wrangling
#  - 4. Data Consistency Checks
#  - 5. Export the dataframe

# %% [markdown]
# ## 1. Import libraries

# %%
# Import libraries

import pandas as pd
import numpy as np
import os

# %%
path = r'/Users/berk/Airbnb_Berlin'

# %% [markdown]
# ## 2. Import data

# %%
# Import airbnb data

df_list = pd.read_csv(os.path.join(path, 'Data', 'Original_Data', 'listings.csv'))

# %%
df_list.head()
# Out:
#        id                                 name  host_id      host_name  \
# 0    3176      Fabulous Flat in great Location     3718         Britta
# 1  251423   2-room I 50 m² I Comfort I Balcony  1023063  Raja Jooseppi
# 2    9991  Geourgeous flat - outstanding views    33852        Philipp
# 3  251486          I 2 Room I 41 m²  I Balcony  1023063  Raja Jooseppi
# 4  251493    2-room I 41 m²  I Terrace > Mitte  1023063  Raja Jooseppi
#
#   neighbourhood_group            neighbourhood  latitude  longitude  \
# 0              Pankow  Prenzlauer Berg Südwest  52.53471   13.41810
# 1               Mitte         Brunnenstr. Nord  52.53867   13.39712
# 2              Pankow  Prenzlauer Berg Südwest  52.53269   13.41805
# 3               Mitte          Brunnenstr. Süd  52.53667   13.39505
# 4               Mitte         Brunnenstr. Nord  52.53881   13.39654
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0  Entire home/apt     83              63                147  2021-01-01
# 1  Entire home/apt    100               3                 14  2023-01-29
# 2  Entire home/apt    180               6                  8  2020-01-04
# 3  Entire home/apt    108               3                 31  2023-03-14
# 4  Entire home/apt     98               3                 15  2023-02-26
#
#    reviews_per_month  calculated_host_listings_count  availability_365  \
# 0               0.88                               1               303
# 1               0.11                               8                93
# 2               0.09                               1                 0
# 3               0.24                               8               104
# 4               0.12                               8                98
#
#    number_of_reviews_ltm                                            license
# 0                      0  First name and Last name: Nicolas Krotz  Conta...
# 1                     10                                  01/Z/NA/003420-15
# 2                      0                                  03/Z/RA/003410-18
# 3                     28                                  01/Z/ZA/006181-16
# 4                     13                                  01/Z/ZA/006180-16

# %%
# Check the shape of the dataframe

df_list.shape
# Out:
# (12049, 18)

# %%
# Check the info of the dataframe

df_list.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12049 entries, 0 to 12048
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              12049 non-null  int64
#  1   name                            12035 non-null  object
#  2   host_id                         12049 non-null  int64
#  3   host_name                       12039 non-null  object
#  4   neighbourhood_group             12049 non-null  object
#  5   neighbourhood                   12049 non-null  object
#  6   latitude                        12049 non-null  float64
#  7   longitude                       12049 non-null  float64
#  8   room_type                       12049 non-null  object
#  9   price                           12049 non-null  int64
#  10  minimum_nights                  12049 non-null  int64
#  11  number_of_reviews               12049 non-null  int64
#  12  last_review                     9773 non-null   object
#  13  reviews_per_month               9773 non-null   float64
#  14  calculated_host_listings_count  12049 non-null  int64
#  15  availability_365                12049 non-null  int64
#  16  number_of_reviews_ltm           12049 non-null  int64
#  17  license                         6967 non-null   object
# dtypes: float64(3), int64(8), object(7)
# memory usage: 1.7+ MB

# %% [markdown]
# ## 3. Data Wrangling

# %%
# Renaming columns

df_list.rename(columns = {'id' : 'listing_id', 'name' : 'listing_name', 'number_of_reviews_ltm' : 'review_in_the_last_year'}, inplace = True)

# %%
df_list.head()
# Out:
#    listing_id                         listing_name  host_id      host_name  \
# 0        3176      Fabulous Flat in great Location     3718         Britta
# 1      251423   2-room I 50 m² I Comfort I Balcony  1023063  Raja Jooseppi
# 2        9991  Geourgeous flat - outstanding views    33852        Philipp
# 3      251486          I 2 Room I 41 m²  I Balcony  1023063  Raja Jooseppi
# 4      251493    2-room I 41 m²  I Terrace > Mitte  1023063  Raja Jooseppi
#
#   neighbourhood_group            neighbourhood  latitude  longitude  \
# 0              Pankow  Prenzlauer Berg Südwest  52.53471   13.41810
# 1               Mitte         Brunnenstr. Nord  52.53867   13.39712
# 2              Pankow  Prenzlauer Berg Südwest  52.53269   13.41805
# 3               Mitte          Brunnenstr. Süd  52.53667   13.39505
# 4               Mitte         Brunnenstr. Nord  52.53881   13.39654
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0  Entire home/apt     83              63                147  2021-01-01
# 1  Entire home/apt    100               3                 14  2023-01-29
# 2  Entire home/apt    180               6                  8  2020-01-04
# 3  Entire home/apt    108               3                 31  2023-03-14
# 4  Entire home/apt     98               3                 15  2023-02-26
#
#    reviews_per_month  calculated_host_listings_count  availability_365  \
# 0               0.88                               1               303
# 1               0.11                               8                93
# 2               0.09                               1                 0
# 3               0.24                               8               104
# 4               0.12                               8                98
#
#    review_in_the_last_year                                            license
# 0                        0  First name and Last name: Nicolas Krotz  Conta...
# 1                       10                                  01/Z/NA/003420-15
# 2                        0                                  03/Z/RA/003410-18
# 3                       28                                  01/Z/ZA/006181-16
# 4                       13                                  01/Z/ZA/006180-16

# %% [markdown]
# ## 4. Data Consistency Checks

# %%
#  Data Consistency Checks the dataframe

df_list.describe()
# Out:
#          listing_id       host_id      latitude     longitude         price  \
# count  1.204900e+04  1.204900e+04  12049.000000  12049.000000  12049.000000
# mean   1.493366e+17  1.262396e+08     52.509474     13.403401    109.135032
# std    2.922496e+17  1.486399e+08      0.033557      0.066236    833.391109
# min    3.176000e+03  1.581000e+03     52.369040     13.118150      0.000000
# 25%    1.424339e+07  1.232012e+07     52.490010     13.365000     48.000000
# 50%    3.242037e+07  5.073615e+07     52.509730     13.411570     75.000000
# 75%    5.205242e+07  2.066996e+08     52.532220     13.438360    120.000000
# max    8.498932e+17  5.057997e+08     52.656110     13.721390  89105.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    12049.000000       12049.000000        9773.000000
# mean        46.419952          35.533405           1.063864
# std         55.934860          76.107987           1.870280
# min          1.000000           0.000000           0.010000
# 25%          2.000000           1.000000           0.120000
# 50%          8.000000           7.000000           0.450000
# 75%         92.000000          32.000000           1.400000
# max       1100.000000        1806.000000          70.730000
#
#        calculated_host_listings_count  availability_365  \
# count                    12049.000000      12049.000000
# mean                         6.166736        113.615155
# std                         17.168217        130.086139
# min                          1.000000          0.000000
# 25%                          1.000000          0.000000
# 50%                          1.000000         48.000000
# 75%                          3.000000        231.000000
# max                        133.000000        365.000000
#
#        review_in_the_last_year
# count             12049.000000
# mean                  9.547182
# std                  21.897381
# min                   0.000000
# 25%                   0.000000
# 50%                   1.000000
# 75%                  10.000000
# max                 703.000000

# %%
# Run a check for missing values in the dataframe

df_list.isnull().sum()
# Out:
# listing_id                           0
# listing_name                        14
# host_id                              0
# host_name                           10
# neighbourhood_group                  0
# neighbourhood                        0
# latitude                             0
# longitude                            0
# room_type                            0
# price                                0
# minimum_nights                       0
# number_of_reviews                    0
# last_review                       2276
# reviews_per_month                 2276
# calculated_host_listings_count       0
# availability_365                     0
# review_in_the_last_year              0
# license                           5082
# dtype: int64

# %%
# Address the missing values using an appropriate method.

df_list.dropna(subset = ['listing_name'], inplace = True)

# %%
df_list.dropna(subset = ['host_name'], inplace = True)

# %%
df_list.dropna(subset = ['last_review'], inplace = True)

# %%
df_list.dropna(subset = ['reviews_per_month'], inplace = True)

# %%
df_list.dropna(subset = ['license'], inplace = True)

# %%
# Check again missing values

df_list.isnull().sum()
# Out:
# listing_id                        0
# listing_name                      0
# host_id                           0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# last_review                       0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# review_in_the_last_year           0
# license                           0
# dtype: int64

# %%
# Check for mixed-type data in the dataframe

for col in df_list.columns.tolist():
  weird = (df_list[[col]].applymap(type) != df_list[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_list[weird]) > 0:
        print (col)

# %% [markdown]
# There is no mixed-type data

# %%
# Run a check for duplicate values in the data

df_list_dups = df_list[df_list.duplicated()]

# %%
df_list_dups.size
# Out:
# 0

# %%
df_list.shape
# Out:
# (6065, 18)

# %% [markdown]
# ## 5. Export the dataframe

# %%
# Export df_list
df_list.to_csv(os.path.join(path, 'Data','Prepared_Data', 'list_cleaned.csv'))
